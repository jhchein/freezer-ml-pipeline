# %%
from azureml.core import Dataset, Workspace, Model, Environment, Experiment
from azureml.core.resource_configuration import ResourceConfiguration
from azureml.core.conda_dependencies import CondaDependencies

from azureml.core import Datastore, Dataset

from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.model import InferenceConfig

from azureml.data import DataType
from azureml.data.datapath import DataPath

from azureml.train.estimator import Estimator

from azureml.core import Webservice
from azureml.core.webservice import AciWebservice
from azureml.exceptions import WebserviceException

from azureml.core import Keyvault

import json

# %% [markdown]
# ### Connect to the Workspace

# %%
ws = Workspace.from_config()
exp = Experiment(ws, "MaxFreezerTemperatureExceeded", _create_in_cloud=True)

# %%
# PARAMS
TIMESERIESLENGTH = 10
THRESHOLD = 180.0
TRAIN_DATA_SPLIT = 0.8

NUMBER_ESTIMATORS = 10

TRAIN_FOLDER_NAME = "train"
TRAIN_FILE_NAME = "train.py"

MODELNAME = "script-classifier"
SERVICENAME = "script-deployment"

MODELFOLDER = "outputs"
MODELFILENAME = "model.pkl"

# %% [markdown]
# ## Prepare
# ### Access data (Blob Storage)

# %%
datastore = Datastore.get(ws, "sensordata")

datapath = DataPath(datastore=datastore, path_on_datastore="/processed/json/**")

dataset = Dataset.Tabular.from_json_lines_files(path=datapath, validate=True, include_path=False, set_column_types={"allevents": DataType.to_string(), "ConnectionDeviceID": DataType.to_string()}, partition_format='/{PartitionDate:yyyy/MM/dd}/')
dataset.register(workspace=ws, name="processed_json", description="Output from Stream Analytics", create_new_version=True)

print("dataset registered")
# Out:
# dataset registered

# %% [markdown]
# ## Train & Test Model
# ### Create experiment
# Define run parameters, compute target, environment and estimator

# %%
compute_target = ComputeTarget(ws, "freezertrain")

script_params = {
    "--timeserieslength": TIMESERIESLENGTH, 
    "--n_estimators": NUMBER_ESTIMATORS, 
    "--threshold": THRESHOLD, 
    "--model_folder": MODELFOLDER, 
    "--model_filename": MODELFILENAME, 
    '--train_data_split': TRAIN_DATA_SPLIT
}

est = Estimator(source_directory=TRAIN_FOLDER_NAME, 
                entry_script=TRAIN_FILE_NAME,
                script_params=script_params,
                inputs=[Dataset.get_by_name(ws, name="processed_json").as_named_input("rawdata")],
                compute_target=compute_target,
                conda_packages=["scikit-learn", "pandas", "cython"],
                pip_packages=['azureml-dataprep[pandas,fuse]==1.4.0', "azureml-defaults==1.1.5", "sktime"]
                )

# %% [markdown]
# ### Run the experiment

# %%
run = exp.submit(est)
run.wait_for_completion(show_output=False, wait_post_processing=True)

# %% [markdown]
# ## Register model

# %%
model = run.register_model(
    model_name=MODELNAME,  # Name of the registered model in your workspace.
    model_path=os.path.join(MODELFOLDER, MODELFILENAME),  # Local file to upload and register as a model.
    tags={
        "area": "freezerchain",
        "type": "classification",
        "purpose": "demonstration",
    },
    properties=None, 
    description="Sktime classifier to predict if freezer chain was interrupted.",
    datasets=[("training_data", dataset)], 
    resource_configuration=ResourceConfiguration(cpu=1, memory_in_gb=0.5))

# %% [markdown]
# ## Build Image

# %%
environment = Environment("sktime_freezer_environment")

cd = CondaDependencies.create(
    conda_packages=["numpy", "cython"],
    pip_packages=[
        "azureml-defaults",
        "inference-schema[numpy-support]",
        "joblib==0.13.*",
        "scikit-learn==0.22.*",
        "pandas==0.23.*",
        "sktime",
    ],
)

environment.python.conda_dependencies = cd

environment.register(workspace=ws)
# Out:
# {
#     "databricks": {
#         "eggLibraries": [],
#         "jarLibraries": [],
#         "mavenLibraries": [],
#         "pypiLibraries": [],
#         "rcranLibraries": []
#     },
#     "docker": {
#         "arguments": [],
#         "baseDockerfile": null,
#         "baseImage": "mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04",
#         "baseImageRegistry": {
#             "address": null,
#             "password": null,
#             "username": null
#         },
#         "enabled": false,
#         "sharedVolumes": true,
#         "shmSize": null
#     },
#     "environmentVariables": {
#         "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#     },
#     "inferencingStackVersion": null,
#     "name": "sktime_freezer_environment",
#     "python": {
#         "baseCondaEnvironment": null,
#         "condaDependencies": {
#             "channels": [
#                 "anaconda",
#                 "conda-forge"
#             ],
#             "dependencies": [
#                 "python=3.6.2",
#                 {
#                     "pip": [
#                         "azureml-defaults~=1.3.0",
#                         "inference-schema[numpy-support]",
#                         "joblib==0.13.*",
#                         "scikit-learn==0.22.*",
#                         "pandas==0.23.*",
#                         "sktime"
#                     ]
#                 },
#                 "numpy",
#                 "cython"
#             ],
#             "name": "azureml_d7b3f6d338e8e466cdd2748eb6688dfd"
#         },
#         "condaDependenciesFile": null,
#         "interpreterPath": "python",
#         "userManagedDependencies": false
#     },
#     "r": null,
#     "spark": {
#         "packages": [],
#         "precachePackages": true,
#         "repositories": []
#     },
#     "version": "1"
# }

# %% [markdown]
# ## Deploy Webservice

# %%
try:
    Webservice(ws, SERVICENAME).delete()
    print("deleted existing Webservice.")
except WebserviceException:
    pass

inference_config = InferenceConfig(
    entry_script="score.py", 
    source_directory="deployment", 
    environment=environment)

aci_config = AciWebservice.deploy_configuration(cpu_cores=1, memory_gb=1,)

service = Model.deploy(
    workspace=ws,
    name=SERVICENAME,
    models=[model],
    inference_config=inference_config,
    deployment_config=aci_config,
)

service.wait_for_deployment(show_output=True)
    
print(f"Scoring Uri: '{service.scoring_uri}'")
# Out:
# deleted existing Webservice.
# Running..................................
# Succeeded
# ACI service creation operation finished, operation "Succeeded"
# Scoring Uri: 'http://eeed9067-ff18-4cde-872d-4b2b7f0eb368.westeurope.azurecontainer.io/score'

# %% [markdown]
# ## Bonus: Store Endpoint in Key Vault

# %%
keyvault = ws.get_default_keyvault()
keyvault.set_secret(name="webservice-name", value = SERVICENAME)
keyvault.set_secret(name="MLENDPOINT", value = service.scoring_uri)

# %% [markdown]
# # Test webservice deployment

# %%
keyvault = ws.get_default_keyvault()
service = Webservice(ws, keyvault.get_secret("webservice-name"))

# %%
with open("deployment/sample_data.json", "r") as fh:
    sample_data = json.loads(fh.read())

input_payload = json.dumps(sample_data)
output = service.run(input_payload)

# print(input_payload)
print(output)
# Out:
# {'result': True, 'ConnectionDeviceId': 'milkbottleEdge', 'timeCreatedStart': '2020-04-07T05:51:01.7604291Z', 'timeCreatedEnd': '2020-04-07T05:51:56.9882857Z', 'hasError': False, 'errorMessage': None}

# %%
print(service.get_logs())
# Out:
# 2020-06-17T07:59:08,229133534+00:00 - iot-server/run
# 2020-06-17T07:59:08,229183834+00:00 - rsyslog/run
# 2020-06-17T07:59:08,230403340+00:00 - gunicorn/run
# 2020-06-17T07:59:08,242731203+00:00 - nginx/run
# /usr/sbin/nginx: /azureml-envs/azureml_2852d664a66d5fa66708d97733323a4e/lib/libcrypto.so.1.0.0: no version information available (required by /usr/sbin/nginx)
# /usr/sbin/nginx: /azureml-envs/azureml_2852d664a66d5fa66708d97733323a4e/lib/libcrypto.so.1.0.0: no version information available (required by /usr/sbin/nginx)
# /usr/sbin/nginx: /azureml-envs/azureml_2852d664a66d5fa66708d97733323a4e/lib/libssl.so.1.0.0: no version information available (required by /usr/sbin/nginx)
# /usr/sbin/nginx: /azureml-envs/azureml_2852d664a66d5fa66708d97733323a4e/lib/libssl.so.1.0.0: no version information available (required by /usr/sbin/nginx)
# /usr/sbin/nginx: /azureml-envs/azureml_2852d664a66d5fa66708d97733323a4e/lib/libssl.so.1.0.0: no version information available (required by /usr/sbin/nginx)
# EdgeHubConnectionString and IOTEDGE_IOTHUBHOSTNAME are not set. Exiting...
# 2020-06-17T07:59:08,513314685+00:00 - iot-server/finish 1 0
# 2020-06-17T07:59:08,521442427+00:00 - Exit code 1 is normal. Not restarting iot-server.
# Starting gunicorn 19.9.0
# Listening at: http://127.0.0.1:31311 (15)
# Using worker: sync
# worker timeout is set to 300
# Booting worker with pid: 41
# Initialized PySpark session.
# Initializing logger
# Starting up app insights client
# Starting up request id generator
# Starting up app insight hooks
# Invoking user's init function
# /azureml-envs/azureml_2852d664a66d5fa66708d97733323a4e/lib/python3.6/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.preprocessing.label module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.preprocessing. Anything that cannot be imported from sklearn.preprocessing is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /azureml-envs/azureml_2852d664a66d5fa66708d97733323a4e/lib/python3.6/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.ensemble.forest module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /azureml-envs/azureml_2852d664a66d5fa66708d97733323a4e/lib/python3.6/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.ensemble.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# Model loaded.
# Users's init has completed successfully
# Scoring timeout is found from os.environ: 60000 ms
# Swagger file not present
# 404
# 127.0.0.1 - - [17/Jun/2020:07:59:23 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "Go-http-client/1.1"
# Swagger file not present
# 404
# 127.0.0.1 - - [17/Jun/2020:07:59:27 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "Go-http-client/1.1"
# Swagger file not present
# 404
# 127.0.0.1 - - [17/Jun/2020:07:59:28 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "Go-http-client/1.1"
# Validation Request Content-Type
# Received input: {"allevents": [{"temperature": 253.36034838918548, "ambienttemperature": 21.40830011289022, "timeCreated": "2020-04-07T05:51:01.7604291Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.05124575297808, "ambienttemperature": 21.136742240114483, "timeCreated": "2020-04-07T05:51:06.7828299Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.2022190760825, "ambienttemperature": 21.170109719350055, "timeCreated": "2020-04-07T05:51:11.8052877Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.3382503375583, "ambienttemperature": 20.685200958598966, "timeCreated": "2020-04-07T05:51:16.8240122Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.7035658367454, "ambienttemperature": 21.441863834365208, "timeCreated": "2020-04-07T05:51:21.8444985Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.79429884547972, "ambienttemperature": 21.133470642675398, "timeCreated": "2020-04-07T05:51:26.8649112Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.5150009936251, "ambienttemperature": 20.999759158817938, "timeCreated": "2020-04-07T05:51:31.8850267Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.053821995646, "ambienttemperature": 20.710163587802167, "timeCreated": "2020-04-07T05:51:36.9044276Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 252.90450877226107, "ambienttemperature": 21.114827556356243, "timeCreated": "2020-04-07T05:51:41.9245882Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 252.68252249862124, "ambienttemperature": 20.994519245109764, "timeCreated": "2020-04-07T05:51:46.9451114Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 252.32300171969538, "ambienttemperature": 20.776223332284122, "timeCreated": "2020-04-07T05:51:51.9680349Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 251.90452107899043, "ambienttemperature": 21.485664722968668, "timeCreated": "2020-04-07T05:51:56.9882857Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}], "ConnectionDeviceId": "milkbottleEdge"}
# Headers passed in (total 11):
# 	Host: localhost:5001
# 	X-Real-Ip: 127.0.0.1
# 	X-Forwarded-For: 127.0.0.1
# 	X-Forwarded-Proto: http
# 	Connection: close
# 	Content-Length: 2688
# 	User-Agent: python-requests/2.23.0
# 	Accept: application/json
# 	Accept-Encoding: gzip, deflate
# 	Content-Type: application/json
# 	X-Ms-Request-Id: e757674e-930e-4ca8-ba15-7ef395a52cda
# Scoring Timer is set to 60.0 seconds
# started run.
# loading json.
# json loaded.
# time_created_start: 2020-04-07T05:51:01.7604291Z
# time_created_end: 2020-04-07T05:51:56.9882857Z
# temperature_data: [253.36034838918548, 253.05124575297808, 253.2022190760825, 253.3382503375583, 253.7035658367454, 253.79429884547972, 253.5150009936251, 253.053821995646, 252.90450877226107, 252.68252249862124, 252.32300171969538, 251.90452107899043]
# ConnectionDeviceId: 'milkbottleEdge'
# 200
# 127.0.0.1 - - [17/Jun/2020:07:59:28 +0000] "POST /score HTTP/1.0" 200 199 "-" "python-requests/2.23.0"
# Swagger file not present
# 404
# 127.0.0.1 - - [17/Jun/2020:07:59:29 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "Go-http-client/1.1"
# Swagger file not present
# 404
# 127.0.0.1 - - [17/Jun/2020:07:59:29 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "Go-http-client/1.1"
# Validation Request Content-Type
# Received input: {"allevents": [{"temperature": 253.36034838918548, "ambienttemperature": 21.40830011289022, "timeCreated": "2020-04-07T05:51:01.7604291Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.05124575297808, "ambienttemperature": 21.136742240114483, "timeCreated": "2020-04-07T05:51:06.7828299Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.2022190760825, "ambienttemperature": 21.170109719350055, "timeCreated": "2020-04-07T05:51:11.8052877Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.3382503375583, "ambienttemperature": 20.685200958598966, "timeCreated": "2020-04-07T05:51:16.8240122Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.7035658367454, "ambienttemperature": 21.441863834365208, "timeCreated": "2020-04-07T05:51:21.8444985Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.79429884547972, "ambienttemperature": 21.133470642675398, "timeCreated": "2020-04-07T05:51:26.8649112Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.5150009936251, "ambienttemperature": 20.999759158817938, "timeCreated": "2020-04-07T05:51:31.8850267Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.053821995646, "ambienttemperature": 20.710163587802167, "timeCreated": "2020-04-07T05:51:36.9044276Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 252.90450877226107, "ambienttemperature": 21.114827556356243, "timeCreated": "2020-04-07T05:51:41.9245882Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 252.68252249862124, "ambienttemperature": 20.994519245109764, "timeCreated": "2020-04-07T05:51:46.9451114Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 252.32300171969538, "ambienttemperature": 20.776223332284122, "timeCreated": "2020-04-07T05:51:51.9680349Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 251.90452107899043, "ambienttemperature": 21.485664722968668, "timeCreated": "2020-04-07T05:51:56.9882857Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}], "ConnectionDeviceId": "milkbottleEdge"}
# Headers passed in (total 11):
# 	Host: localhost:5001
# 	X-Real-Ip: 127.0.0.1
# 	X-Forwarded-For: 127.0.0.1
# 	X-Forwarded-Proto: http
# 	Connection: close
# 	Content-Length: 2688
# 	User-Agent: python-requests/2.23.0
# 	Accept: application/json
# 	Accept-Encoding: gzip, deflate
# 	Content-Type: application/json
# 	X-Ms-Request-Id: a5148a11-e3d1-4937-af3c-92fc84751c9b
# Scoring Timer is set to 60.0 seconds
# started run.
# loading json.
# json loaded.
# time_created_start: 2020-04-07T05:51:01.7604291Z
# time_created_end: 2020-04-07T05:51:56.9882857Z
# temperature_data: [253.36034838918548, 253.05124575297808, 253.2022190760825, 253.3382503375583, 253.7035658367454, 253.79429884547972, 253.5150009936251, 253.053821995646, 252.90450877226107, 252.68252249862124, 252.32300171969538, 251.90452107899043]
# ConnectionDeviceId: 'milkbottleEdge'
# 200
# 127.0.0.1 - - [17/Jun/2020:07:59:29 +0000] "POST /score HTTP/1.0" 200 199 "-" "python-requests/2.23.0"
# 127.0.0.1 - - [17/Jun/2020:10:46:23 +0000] "POST /boaform/admin/formLogin HTTP/1.0" 404 232 "http://51.124.87.73:80/admin/login.asp" "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:71.0) Gecko/20100101 Firefox/71.0"
# Swagger file not present
# 404
# 127.0.0.1 - - [17/Jun/2020:12:22:24 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "Go-http-client/1.1"
# Validation Request Content-Type
# Received input: {"allevents": [{"temperature": 253.36034838918548, "ambienttemperature": 21.40830011289022, "timeCreated": "2020-04-07T05:51:01.7604291Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.05124575297808, "ambienttemperature": 21.136742240114483, "timeCreated": "2020-04-07T05:51:06.7828299Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.2022190760825, "ambienttemperature": 21.170109719350055, "timeCreated": "2020-04-07T05:51:11.8052877Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.3382503375583, "ambienttemperature": 20.685200958598966, "timeCreated": "2020-04-07T05:51:16.8240122Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.7035658367454, "ambienttemperature": 21.441863834365208, "timeCreated": "2020-04-07T05:51:21.8444985Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.79429884547972, "ambienttemperature": 21.133470642675398, "timeCreated": "2020-04-07T05:51:26.8649112Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.5150009936251, "ambienttemperature": 20.999759158817938, "timeCreated": "2020-04-07T05:51:31.8850267Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.053821995646, "ambienttemperature": 20.710163587802167, "timeCreated": "2020-04-07T05:51:36.9044276Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 252.90450877226107, "ambienttemperature": 21.114827556356243, "timeCreated": "2020-04-07T05:51:41.9245882Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 252.68252249862124, "ambienttemperature": 20.994519245109764, "timeCreated": "2020-04-07T05:51:46.9451114Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 252.32300171969538, "ambienttemperature": 20.776223332284122, "timeCreated": "2020-04-07T05:51:51.9680349Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 251.90452107899043, "ambienttemperature": 21.485664722968668, "timeCreated": "2020-04-07T05:51:56.9882857Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}], "ConnectionDeviceId": "milkbottleEdge"}
# Headers passed in (total 11):
# 	Host: localhost:5001
# 	X-Real-Ip: 127.0.0.1
# 	X-Forwarded-For: 127.0.0.1
# 	X-Forwarded-Proto: http
# 	Connection: close
# 	Content-Length: 2688
# 	User-Agent: python-requests/2.23.0
# 	Accept: application/json
# 	Accept-Encoding: gzip, deflate
# 	Content-Type: application/json
# 	X-Ms-Request-Id: 0c137f27-fffe-48fe-925a-c843defd2b97
# Scoring Timer is set to 60.0 seconds
# started run.
# loading json.
# json loaded.
# time_created_start: 2020-04-07T05:51:01.7604291Z
# time_created_end: 2020-04-07T05:51:56.9882857Z
# temperature_data: [253.36034838918548, 253.05124575297808, 253.2022190760825, 253.3382503375583, 253.7035658367454, 253.79429884547972, 253.5150009936251, 253.053821995646, 252.90450877226107, 252.68252249862124, 252.32300171969538, 251.90452107899043]
# ConnectionDeviceId: 'milkbottleEdge'
# 200
# 127.0.0.1 - - [17/Jun/2020:12:22:42 +0000] "POST /score HTTP/1.0" 200 199 "-" "python-requests/2.23.0"
# Validation Request Content-Type
# Received input: {"allevents": [{"temperature": 253.36034838918548, "ambienttemperature": 21.40830011289022, "timeCreated": "2020-04-07T05:51:01.7604291Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.05124575297808, "ambienttemperature": 21.136742240114483, "timeCreated": "2020-04-07T05:51:06.7828299Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.2022190760825, "ambienttemperature": 21.170109719350055, "timeCreated": "2020-04-07T05:51:11.8052877Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.3382503375583, "ambienttemperature": 20.685200958598966, "timeCreated": "2020-04-07T05:51:16.8240122Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.7035658367454, "ambienttemperature": 21.441863834365208, "timeCreated": "2020-04-07T05:51:21.8444985Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.79429884547972, "ambienttemperature": 21.133470642675398, "timeCreated": "2020-04-07T05:51:26.8649112Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.5150009936251, "ambienttemperature": 20.999759158817938, "timeCreated": "2020-04-07T05:51:31.8850267Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 253.053821995646, "ambienttemperature": 20.710163587802167, "timeCreated": "2020-04-07T05:51:36.9044276Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 252.90450877226107, "ambienttemperature": 21.114827556356243, "timeCreated": "2020-04-07T05:51:41.9245882Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 252.68252249862124, "ambienttemperature": 20.994519245109764, "timeCreated": "2020-04-07T05:51:46.9451114Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 252.32300171969538, "ambienttemperature": 20.776223332284122, "timeCreated": "2020-04-07T05:51:51.9680349Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}, {"temperature": 251.90452107899043, "ambienttemperature": 21.485664722968668, "timeCreated": "2020-04-07T05:51:56.9882857Z", "ConnectionDeviceId": "milkbottleEdge", "ConnectionDeviceGenerationId": "637211838651873534"}], "ConnectionDeviceId": "milkbottleEdge"}
# Headers passed in (total 11):
# 	Host: localhost:5001
# 	X-Real-Ip: 127.0.0.1
# 	X-Forwarded-For: 127.0.0.1
# 	X-Forwarded-Proto: http
# 	Connection: close
# 	Content-Length: 2688
# 	User-Agent: python-requests/2.23.0
# 	Accept: application/json
# 	Accept-Encoding: gzip, deflate
# 	Content-Type: application/json
# 	X-Ms-Request-Id: 95125673-92f0-4053-a784-0598299c9f92
# Scoring Timer is set to 60.0 seconds
# started run.
# loading json.
# json loaded.
# time_created_start: 2020-04-07T05:51:01.7604291Z
# time_created_end: 2020-04-07T05:51:56.9882857Z
# temperature_data: [253.36034838918548, 253.05124575297808, 253.2022190760825, 253.3382503375583, 253.7035658367454, 253.79429884547972, 253.5150009936251, 253.053821995646, 252.90450877226107, 252.68252249862124, 252.32300171969538, 251.90452107899043]
# ConnectionDeviceId: 'milkbottleEdge'
# 200
# 127.0.0.1 - - [17/Jun/2020:12:22:46 +0000] "POST /score HTTP/1.0" 200 199 "-" "python-requests/2.23.0"
